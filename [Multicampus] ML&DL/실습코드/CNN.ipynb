# %% [markdown]
# # CNN With Mnist

# %%
import tensorflow as tf
import matplotlib.pyplot as plt
import numpy as np

# %%
(X_train, y_train), (X_test, y_test) = tf.keras.datasets.mnist.load_data()
X_train.shape, y_train.shape
# Out:
# ...
# 11493376/11490434 [==============================] - 0s 0us/step
# ((60000, 28, 28), (60000,))

# %%
from tensorflow.keras import layers

# %%
model = tf.keras.Sequential([
                             # (28.28,3)
                             layers.Conv2D(64, (3,3), activation='relu'), # (3*3 +1) * 64 = 640
                             layers.MaxPooling2D((2, 2)),
                             layers.Conv2D(128, (3,3), activation='relu'), # (64*3*3 +1) *128 = 
                             layers.MaxPooling2D((2,2)),
                             layers.Conv2D(256, (3,3), activation='relu'), # (3*3*128 + 1)* 256
                             layers.MaxPooling2D((2,2)),
                             layers.Flatten(),
                             layers.Dense(32, activation='relu'),
                             layers.Dense(10, activation='softmax')
])

# %%
28*28*3 * 1000 => 2352000
# Out:
# 2352

# %%
X_train.shape, y_train.shape
# Out:
# ((60000, 28, 28), (60000,))

# %%
X_train_, X_test_ = X_train[..., tf.newaxis], X_test[..., tf.newaxis]

# %%
X_train_.shape
# Out:
# (60000, 28, 28, 1)

# %%
model.compile(optimizer='adam',
              loss='sparse_categorical_crossentropy',
              metrics='accuracy')

# %%
X_train_, X_test_ = X_train_/255, X_test_/255

# %%
model.fit(X_train_, y_train, epochs=3, validation_split=0.2)
# Out:
# Epoch 1/3
# WARNING:tensorflow:Layer conv2d_6 is casting an input tensor from dtype float64 to the layer's dtype of float32, which is new behavior in TensorFlow 2.  The layer has dtype float32 because it's dtype defaults to floatx.
#
# If you intended to run this layer in float32, you can safely ignore this warning. If in doubt, this warning is likely only an issue if you are porting a TensorFlow 1.X model to TensorFlow 2.
#
# To change all layers to have dtype float64 by default, call `tf.keras.backend.set_floatx('float64')`. To change just this layer, pass dtype='float64' to the layer constructor. If you are the author of this layer, you can disable autocasting by passing autocast=False to the base Layer constructor.
#
# 1500/1500 [==============================] - 142s 94ms/step - loss: 0.1920 - accuracy: 0.9406 - val_loss: 0.0749 - val_accuracy: 0.9768
# Epoch 2/3
# ...

# %%
model.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# conv2d_6 (Conv2D)            multiple                  640
# _________________________________________________________________
# max_pooling2d_6 (MaxPooling2 multiple                  0
# _________________________________________________________________
# conv2d_7 (Conv2D)            multiple                  73856
# _________________________________________________________________
# max_pooling2d_7 (MaxPooling2 multiple                  0
# _________________________________________________________________
# conv2d_8 (Conv2D)            multiple                  295168
# _________________________________________________________________
# max_pooling2d_8 (MaxPooling2 multiple                  0
# _________________________________________________________________
# flatten_2 (Flatten)          multiple                  0
# ...

# %%
# Out:
# 1875/1875 [==============================] - 38s 20ms/step - loss: 0.0420 - accuracy: 0.9870
# [0.042028654366731644, 0.9869999885559082]

# %%
(3*3*128 + 1)* 256
# Out:
# 295168

# %%
(64*3*3 +1) *128
# Out:
# 73856

# %%
257*32
# Out:
# 8224

# %% [markdown]
# # Fashion Mnist

# %%
(x_train, y_train), (x_test, y_test) = tf.keras.datasets.fashion_mnist.load_data()

# %%
x_train.shape
# Out:
# (60000, 28, 28)

# %%
X_train_, X_test_ = x_train[..., tf.newaxis], x_test[..., tf.newaxis]
X_train_, X_test_ = X_train_/255, X_test_/255

# %%
model = tf.keras.Sequential([
                             # (28.28,3)
                             layers.Conv2D(64, (3,3), activation='relu'), 
                             layers.MaxPooling2D((2, 2)),
                             layers.Conv2D(128, (3,3), activation='relu'), 
                             layers.MaxPooling2D((2,2)),
                             layers.Conv2D(256, (3,3), activation='relu'), 
                             layers.MaxPooling2D((2,2)),
                            
                             layers.Flatten(),
                             layers.Dense(32, activation='relu'),
                             layers.Dense(10, activation='softmax')
])

# %%
model.compile(optimizer='adam',
              loss='sparse_categorical_crossentropy',
              metrics='accuracy')

model.fit(X_train_, y_train, epochs=3, validation_split=0.2)

# model.evaluate(X_train_, y_train)
# Out:
# Epoch 1/3
# WARNING:tensorflow:Layer conv2d_47 is casting an input tensor from dtype float64 to the layer's dtype of float32, which is new behavior in TensorFlow 2.  The layer has dtype float32 because it's dtype defaults to floatx.
#
# If you intended to run this layer in float32, you can safely ignore this warning. If in doubt, this warning is likely only an issue if you are porting a TensorFlow 1.X model to TensorFlow 2.
#
# To change all layers to have dtype float64 by default, call `tf.keras.backend.set_floatx('float64')`. To change just this layer, pass dtype='float64' to the layer constructor. If you are the author of this layer, you can disable autocasting by passing autocast=False to the base Layer constructor.
#
# 1500/1500 [==============================] - 6s 4ms/step - loss: 0.5821 - accuracy: 0.7882 - val_loss: 0.4285 - val_accuracy: 0.8413
# Epoch 2/3
# ...

# %%
import tensorflow as tf
import matplotlib.pyplot as plt
from tensorflow.keras import layers

# %%
(X_train, y_train), (X_test, y_test) = tf.keras.datasets.cifar10.load_data()

# %%
X_train[..., tf.newaxis]
# Out:
# array([[[[[ 59],
#           [ 62],
#           [ 63]],
#
#          [[ 43],
#           [ 46],
#           [ 45]],
#
#          [[ 50],
#           [ 48],
#           [ 43]],
#
#          ...,
#
#          [[158],
#           [132],
#           [108]],
#
#          [[152],
#           [125],
#           [102]],
#
#          [[148],
#           [124],
#           [103]]],
#
#
#         [[[ 16],
#           [ 20],
#           [ 20]],
#
#          [[  0],
#           [  0],
#           [  0]],
#
#          [[ 18],
#           [  8],
#           [  0]],
#
#          ...,
#
#          [[123],
#           [ 88],
#           [ 55]],
#
#          [[119],
#           [ 83],
#           [ 50]],
#
#          [[122],
#           [ 87],
#           [ 57]]],
#
#
#         [[[ 25],
#           [ 24],
#           [ 21]],
#
#          [[ 16],
#           [  7],
#           [  0]],
#
#          [[ 49],
#           [ 27],
#           [  8]],
#
#          ...,
#
#          [[118],
#           [ 84],
# ...

# %%
X_train.shape, y_train.shape
# Out:
# ((50000, 32, 32, 3), (50000, 1))

# %%
plt.imshow(X_train[0])

# %%
X_train_, X_test_ = X_train/255, X_test/255

# %%
X_train.shape
# Out:
# (50000, 32, 32, 3)

# %%
model = tf.keras.Sequential([
                             # (32.32,3)
                             layers.Conv2D(32, (3,3), activation='relu', padding='SAME'), 
                             layers.MaxPooling2D((2, 2)),

                             layers.Conv2D(64, (3,3), activation='relu', padding='SAME'), 
                             layers.Conv2D(64, (3,3), activation='relu', padding='SAME'), 
                             layers.MaxPooling2D((2,2)),

                             layers.Conv2D(128, (3,3), activation='relu', padding="SAME"),
                             layers.MaxPooling2D((2,2)),

                             layers.Conv2D(256, (3,3), activation='relu', padding="SAME"),
                             layers.MaxPooling2D((2,2)),

                             layers.Conv2D(512, (3,3), activation='relu', padding="SAME"),
                             layers.MaxPooling2D((2,2)),
                             


                             layers.Flatten(),
                             layers.Dense(128, activation='relu'),
                             layers.Dense(10, activation='softmax')
])

# %%
model.compile(optimizer="adam",
              loss="sparse_categorical_crossentropy",
              metrics=['accuracy'])

model.fit(X_train_, y_train, validation_split=0.2, epochs=10)

model.evaluate(X_train_, y_train)
# Out:
# Epoch 1/10
# WARNING:tensorflow:Layer conv2d_107 is casting an input tensor from dtype float64 to the layer's dtype of float32, which is new behavior in TensorFlow 2.  The layer has dtype float32 because it's dtype defaults to floatx.
#
# If you intended to run this layer in float32, you can safely ignore this warning. If in doubt, this warning is likely only an issue if you are porting a TensorFlow 1.X model to TensorFlow 2.
#
# To change all layers to have dtype float64 by default, call `tf.keras.backend.set_floatx('float64')`. To change just this layer, pass dtype='float64' to the layer constructor. If you are the author of this layer, you can disable autocasting by passing autocast=False to the base Layer constructor.
#
# 1250/1250 [==============================] - 8s 7ms/step - loss: 1.6430 - accuracy: 0.3879 - val_loss: 1.2743 - val_accuracy: 0.5316
# Epoch 2/10
# ...

# %%
model.summary()
# Out:
# Model: "sequential_18"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# conv2d_95 (Conv2D)           multiple                  896
# _________________________________________________________________
# max_pooling2d_94 (MaxPooling multiple                  0
# _________________________________________________________________
# conv2d_96 (Conv2D)           multiple                  18496
# _________________________________________________________________
# max_pooling2d_95 (MaxPooling multiple                  0
# _________________________________________________________________
# conv2d_97 (Conv2D)           multiple                  73856
# _________________________________________________________________
# conv2d_98 (Conv2D)           multiple                  147584
# _________________________________________________________________
# max_pooling2d_96 (MaxPooling multiple                  0
# ...

# %% [markdown]
# ## feature map 확인하기

# %%
model.layers[0]

# %%
X_train[0].shape
# Out:
# (32, 32, 3)

# %%
model.save_weights('sample')

# %%
# !ls
# Out:
# sample_data

# %%
model.load_weights('sample')
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/training/py_checkpoint_reader.py in NewCheckpointReader(filepattern)
#      94   try:
# ---> 95     return CheckpointReader(compat.as_bytes(filepattern))
#      96   # TODO(b/143319754): Remove the RuntimeError casting logic once we resolve the
#
# RuntimeError: Unsuccessful TensorSliceReader constructor: Failed to find any matching files for sample
#
# During handling of the above exception, another exception occurred:
#
# NotFoundError                             Traceback (most recent call last)
# <ipython-input-5-ca0727557312> in <module>()
# ----> 1 model.load_weights('sample')
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/keras/engine/training.py in load_weights(self, filepath, by_name, skip_mismatch)
# ...

# %%
X_train_[:10,:,:,:]

# %%
first_fm = model.layers[0](X_train_[:10000,:,:,:])

# %%
first_fm.shape
# Out:
# TensorShape([10000, 32, 32, 32])

# %%
plt.imshow(X_train_[0])

# %%
model.layers[2]

# %%
img = first_fm[0]
fig = plt.figure(figsize=(15, 15))

for i in range(32):
    fig.add_subplot(7,5, i+1)
    plt.imshow(first_fm[0, :, :, i])

# %%
after_pool = model.layers[1](first_fm)
after_second_conv = model.layers[2](after_pool)
after_second_conv[0]

# %%
after_second_conv[0].shape
# Out:
# TensorShape([16, 16, 64])

# %%
fig = plt.figure(figsize=(15, 15))

for i in range(64):
    fig.add_subplot(8, 8, i+1)
    plt.imshow(after_second_conv[0, :, :, i])

# %%
import tensorflow_datasets as tfds

# %%
tfds
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-111-8bf1759b723c> in <module>()
# ----> 1 tfds.image_classification.flowers.TFFlowers
#
# AttributeError: module 'tensorflow_datasets' has no attribute 'image_classification'
