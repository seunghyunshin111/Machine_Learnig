# %% [markdown]
# #17. 크롤링심화과제 [ 웹툰댓글 가져오기 ]

# %% [markdown]
# #### 1번.
# 네이버 모든 웹툰의 ID값과 최신화 정보를 크롤링해서,
# 딕셔너리(webtoon_dict)로 저장해보세요.

# %%
# webtoon_dict = {
#   '신의 탑' : {'current_no' : 485,
              #     'title' : '신의탑',
              #     'title_id' : 725586,
              #     'link' : 'webtoon/list.nhn?titleId=725586&weekday=mon'
              # }

# %% [markdown]
# #### 2번.
# 원하는 웹툰 제목을 입력하면, 해당 웹툰의 ID값과 최신화정보를 출력해보세요.

# %% [markdown]
# #### 3번.
# 원하는 웹툰의 모든 화의 모든 댓글을 크롤링해서 csv로 저장해보세요.
