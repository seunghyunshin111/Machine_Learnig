# %% [markdown]
# # 함수(Function)

# %% [markdown]
# ### 변수 Review : 변수는 왜 필요한가?

# %%
#변수 review
234543 * 2, 234543 * 3 #반복해서 나오는 데이터를 변수로 선언
# Out:
# (469086, 703629)

# %%
var = 234543
var * 2, var * 3
# Out:
# (469086, 703629)

# %% [markdown]
# - 변수는 데이터를 재사용하기 위해서 사용한다.
# - 변수는 데이터를 효율적으로 관리하기 위해서 사용한다.

# %%
num_list = []

for i in range(3):
    num = input('input any number:')
    num_list.append(num)
num_list
# Out:
# input any number:1
# input any number:2
# input any number:3
# ['1', '2', '3']

# %% [markdown]
# ### 함수는 왜 필요한가?

# %%
data_list = []

for i in range(5):
    data = input('input any data:')
    data_list.append(data)
data_list
# Out:
# input any data:hello
# input any data:how
# input any data:are
# input any data:you
# input any data:imfinethankyou and you
# ['hello', 'how', 'are', 'you', 'imfinethankyou and you']

# %% [markdown]
# 위와 같이 반복되는 코드를 재사용하기 위해서 함수를 사용한다.

# %%
def create_data_list(): #함수 정의(생성) var = 234543
    data_list = []

    for i in range(5):
        data = input('input any data:')
        data_list.append(data)

# %%
create_data_list() #함수 호출(사용) var
# Out:
# input any data:hello
# input any data:its ,e
# input any data:adell
# input any data:bye
# input any data:bye

# %% [markdown]
# ### 함수의 종류
# 1) input X, output X : 함수 내 코드 그대로만 사용가능
# 2) input O, output X : 함수 내 코드를 input인자를 사용하여 변경 가능
# 3) input X, output O : 함수 내의 변수를 함수 밖으로 return 가능
# 4) input O, output O : 코드 변경 O, 함수 내 변수 return O

# %% [markdown]
# #### 함수가 품고 있는 코드를 변경해서 사용하고 싶다면?

# %%
def create_data_list_2(n_iter, name_var): #함수 정의(생성) var = 234543
    data_list = []

    for i in range(n_iter):
        data = input('input any {}:'.format(name_var))
        data_list.append(data)

# %%
create_data_list_2(2, 'number') #반복할 횟수, 변수 이름을 호출 시에 정해줌.
# Out:
# input any number:3
# input any number:4

# %%
create_data_list_2(name_var='number', n_iter=2)
# print(data_list)
# Out:
# input any number:3
# input any number:4
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-697a49f96bd3> in <module>()
#       1 create_data_list_2(name_var='number', n_iter=2)
# ----> 2 print(data_list)
#
# NameError: name 'data_list' is not defined

# %% [markdown]
# #### 함수 내의 변수를 함수 밖에서 사용하고 싶다면?

# %%
def create_data_list_3(): #함수 정의(생성) var = 234543
    data_list = []

    for i in range(5):
        data = input('input any data:')
        data_list.append(data)
    return data_list

# %%
data = create_data_list_3()
# print(data_list)
# print(data)
# print(create_data_list_3())
# Out:
# input any data:1
# input any data:2
# input any data:3
# input any data:4
# input any data:5
# input any data:1
# input any data:2
# input any data:3
# input any data:4
# input any data:6
# ['1', '2', '3', '4', '6']

# %%
data

# %% [markdown]
# #### 함수 내 코드도 변경하고, 함수 내 변수도 밖에서 사용하려면?

# %%
def create_data_list_4(n_iter, name_var): #함수 정의(생성) var = 234543
    data_list = []

    for i in range(n_iter):
        data = input('input any {}:'.format(name_var))
        data_list.append(data)
    return data_list

# %%
data = create_data_list_4(3, 'key')
print(data)
# Out:
# input any key:1
# input any key:2
# input any key:3
# ['1', '2', '3']

# %% [markdown]
# #### 문제) 이름과 폰번호, 이메일주소를 input인자로 받아서,  이 3가지 데이터를dictionary형태로 묶어서 return해주는 함수를 만들어보세요.
# 함수 이름 : create_info_dict

# %%
#직접 풀어봅시다.

# %% [markdown]
# #####풀이

# %%
def create_info_dict(name, phone, email):
    data = {'name': name,
           'phone-number': phone,
           'email': email}
    return data

# %%
name = input('name:')
phone = input('phone-number:')
email = input('email adress:')
print('result:', create_info_dict(name, phone, email))
# Out:
# name:1
# phone-number:2
# email adress:3
# result: {'name': '1', 'phone-number': '2', 'email': '3'}

# %% [markdown]
# - 함수 호출 시, 인자를 변수를 넣어도 된다.
# - return이 있는 함수를 호출 시, 반드시 return에대한 변수를 선언해줘야 하는 것은 아니다.

# %%
# 숫자 3개 입력받으셔서, 평균과 합계를 리턴해주는 함수를 만들어보세요.
def sum_and_mean(num1, num2, num3): #num1, num2, num3 = 34565, 454532, 234234
  sm = num1 + num2 + num3
  avg = sm/3
  return sm, avg

# %%
sum_, avg_ = sum_and_mean(34565, 454532, 234234)
sum_, avg_
# Out:
# (723331, 241110.33333333334)

# %% [markdown]
# ### Default값 설정

# %% [markdown]
# #### 함수를 호출할 때, 함수의 입력 인자 개수를 맞춰주지 않으면 어떻게 될까?
#
# create_info_dict의 input인자는 3개다.
# 만약 input인자를 2개만 넘겨주면 어떻게 될까?
# type error 발생!
#
# 그럼 어떻게 바꿔줘야 할까?

# %%
print?

# %%
print()

# %%
def create_info_dict(name, phone='010-0000-0000', email='@.com'):
    data = {'name': name,
           'phone-number': phone,
           'email': email}
    return data

# %%
create_info_dict('ardino', email='naver.com')
# Out:
# {'email': 'naver.com', 'name': 'ardino', 'phone-number': '010-0000-0000'}

# %%
#print함수를 기억해보자.
print(4)
print(4, end='*')
print()
print(4, 5, sep=':', end='*')
# Out:
# 4
# 4*
# 4:5*

# %% [markdown]
# ### 가변인자 설정

# %% [markdown]
# #### 입력인자 개수를 상황에 따라 가변적으로 조절해도 되는 함수를 만들려면 어떻게 해야할까?
#
#   가변인자 설정
#
#   - 가변인자 : *인자이름
#   - 특징 : 가변인자의 type은 tuple이다.

# %%
def print_data(*data): # data = 1, 2, 3, 4, 5
  print(data)

# print_data(1, 2, 3, 4, 5)
# print_data(1, 2, 3)
# print_data(1)
# print_data()

info = [1, 2, 3, 4, 5]
print_data(*info)
info = [1, 2, 3]
print_data(*info)
info = [1]
print_data(*info)
info = []
print_data(*info)
# Out:
# (1, 2, 3, 4, 5)
# (1, 2, 3)
# (1,)
# ()

# %%
def print_data(*data): #*data = 가변인자
    print('data: ', data)
    
    data_list = list(data) #리스트로 형변환
    print('형변환: ', data_list)

    # 언패킹 (데이터 3개라고 가정)
    # data1, data2, data3 = data[0], data[1], data[2] 
    # print('언패킹 :', data1, data2, data3)
#     return data_list

# %%
# print_data()
# print_data(1)
# print_data(1, 2, 3) #함수 호출 시, data로 대입

# %%
print_data('원재', '디노', '온즈')
# Out:
# data:  ('원재', '디노', '온즈')
# 형변환:  ['원재', '디노', '온즈']

# %% [markdown]
# #### 여러개의 데이터를 리스트로 묶어서 넣어주면 어떻게 될까?
#
# 함수 호출 시, data로 직접 대입하지 않고,
# 변수로 대입하여 호출해보자.

# %%
sample_list = [1, 2, 3]
print_data(*sample_list)
# Out:
# data:  (1, 2, 3)
# 형변환:  [1, 2, 3]

# %% [markdown]
# #### 가변인자를 key값을 가진 딕셔너리 형태의 변수로 선언하고 싶다면?
#
#   가변인자 설정
#
#   - 가변인자 : **인자이름
#   - 특징 : 가변인자의 type은 dictionary이다.

# %%
def print_data_2(**data):
    print(data, type(data))

# %%
print_data_2(name='ardino', phone='010-0000-0000', email='@.com')
# Out:
# {'name': 'ardino', 'phone': '010-0000-0000', 'email': '@.com'} <class 'dict'>

# %% [markdown]
# #### 넣어줄 때도 딕셔너리로 묶어서 넣어주면 어떻게 될까?

# %%
sample_dict = {
    'name': 'ardino',
    'phone': '010',
    'email': 'naver.com'
}
print_data_2(**sample_dict)
# Out:
# {'name': 'ardino', 'phone': '010', 'email': 'naver.com'} <class 'dict'>

# %% [markdown]
# ### 지역변수와 전역변수

# %%
a = 5 # G

def fun1():
  a = 1 # L
  print(a)

def fun2():
  a = 2 # L
  print(a)

def fun3():
  print(a)

def fun4():
  global a
  a = 4
  print(a)

# %%
# fun1()
# fun2()
fun3()
# Out:
# 5

# %%
fun4()
print(a)
# Out:
# 4
# 4

# %% [markdown]
# ### 람다함수 (간단함수)
# def 함수명(인자) 가 과하게 느껴질만큼
# 간단한 코드만 재사용/관리 하고 싶은 경우

# %%
mySquare = lambda x : x**2

# %%
mySquare(2)
# Out:
# 4

# %%
mySimpleFunc = lambda x,y,z : 2*x + 3*y + z

# %%
mySimpleFunc(1, 2, 3)
# Out:
# 11

# %% [markdown]
# ### 많이쓰는 내장함수들 정리

# %%
myNum = list(range(30))
max(myNum), min(myNum)
# Out:
# (29, 0)

# %%
sum(myNum)
# Out:
# 435

# %%
myNum = [-1, -2, -3]
myNum
# Out:
# [-1, -2, -3]

# %%
abs(myNum[0]), abs(myNum[1]), abs(myNum[2])
# Out:
# (1, 2, 3)

# %%
# 문자열 다루기
#1
"에스프레소 아메리카노 카페라떼 카푸지노".split()
# Out:
# ['에스프레소', '아메리카노', '카페라떼', '카푸지노']

# %%
#2
"에스프레소 ".strip(), "   에스프레소".strip(), "  에스프레소  ".strip()
# Out:
# ('에스프레소', '에스프레소', '에스프레소')

# %%
"  에스프레소  ".rstrip(), "  에스프레소  ".lstrip()
# Out:
# ('  에스프레소', '에스프레소  ')

# %%
"aaaaa에스프레소aaaaa".strip('a')
# Out:
# '에스프레소'

# %%
"abcacacacc에스프레소bbbbccaac".strip('abc')
# Out:
# '에스프레소'

# %%
"에 스 프 레 소".replace(' ', ''), "에a스a프a레a소".replace('a', '')
# Out:
# ('에스프레소', '에스프레소')

# %%
raw_word = "abcacacacc에스프레소bbbbccaac"
raw_word = raw_word.replace('a', '')
raw_word = raw_word.replace('b', '')
raw_word = raw_word.replace('c', '')
raw_word
# Out:
# '에스프레소'

# %%
mulcam = ["서울시", "강남구", "역삼동", "멀티캠퍼스"]

"".join(mulcam)
# Out:
# '서울시강남구역삼동멀티캠퍼스'

# %%
" ".join(mulcam)
# Out:
# '서울시 강남구 역삼동 멀티캠퍼스'

# %%
"-".join(mulcam)
# Out:
# '서울시-강남구-역삼동-멀티캠퍼스'

# %%
mulcam = "서울시 강남구 역삼동 멀티캠퍼스"

key = "멀티캠퍼스"

mulcam.find(key)
# Out:
# 12

# %%
mulcam.find(' ')
# Out:
# 3

# %%
mulcam.index("멀티캠퍼스")
# Out:
# 12

# %%
mulcam.count(' ')
# Out:
# 3

# %%
mtcps = "멀티캠퍼스15층1501호와1502호는B반이다!!!!!!!"

mtcps.isalpha(), "멀티캠퍼스".isalpha()
# Out:
# (False, True)

# %%
mtcps.isdigit(), '15'.isdigit()
# Out:
# (False, True)

# %%
mtcps.isalnum() , "멀티캠퍼스15층1501호와1502호는B반이다".isalnum()
# Out:
# (False, True)

# %%
'Multicampus'.isupper(), 'MULTICAMPUS'.isupper()
# Out:
# (False, True)

# %%
'Multicampus'.upper()
# Out:
# 'MULTICAMPUS'

# %%
'Multicampus'.lower()
# Out:
# 'multicampus'
