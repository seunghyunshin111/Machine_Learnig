# %%
5 + 4
# Out:
# 9

# %%
5 - 4
# Out:
# 1

# %%
5*4
# Out:
# 20

# %%
5/4
# Out:
# 1.25

# %%
5//4
# Out:
# 1

# %%
5%4
# Out:
# 1

# %%
5**4
# Out:
# 625

# %%
100000000
# Out:
# 100000000

# %%
1e8 # 1*10**8
# Out:
# 100000000.0

# %%
# 0.001은 과학적표기법으로 뭘까?
print(1e-3)
# 0.00045 는 뭘까?
4.5e-4
# Out:
# 0.001
# 0.00045

# %%
1e30
# Out:
# 1e+30

# %%
1e8
# Out:
# 100000000.0

# %%
1e16
# Out:
# 1e+16

# %%
1e15
# Out:
# 1000000000000000.0

# %%
1e-15
# Out:
# 1e-15

# %%
1e-14
# Out:
# 1e-14

# %%
1e-13
# Out:
# 1e-13

# %%
1e-5
# Out:
# 1e-05

# %%
1e-4
# Out:
# 0.0001

# %% [markdown]
# 비교연산자

# %%
5 > 3
# Out:
# True

# %%
5 == 3 # 5 = 3 대입
# Out:
# False

# %%
5 != 3
# Out:
# True

# %%
5 >= 3
# Out:
# True

# %%
5 <= 3
# Out:
# False

# %%
# 5 => 3

# %% [markdown]
# 논리값

# %%
True # 0이 아닌 것, ""이 아닌 것
# Out:
# True

# %%
False # 0, ""
# Out:
# False

# %% [markdown]
# 문자

# %%
"안녕?"
# Out:
# '안녕?'

# %%
'응 안녕~'
# Out:
# '응 안녕~'

# %%
"1"
# Out:
# '1'

# %%
"0"
# Out:
# '0'

# %%
" "
# Out:
# ' '

# %%
""
# Out:
# ''
