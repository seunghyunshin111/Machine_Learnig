# %%
print("hello, python")
# Out:
# hello, python

# %%
print("hello, multicampus")
# Out:
# hello, multicampus

# %% [markdown]
# # 제목1
# ## 제목2
# 오늘의 주제는
# 개발환경세팅이다.
#
# - 소분류1
# * 소분류2

# %%
print("hello, DS") # 출력 예시 코드
# Out:
# hello, DS

# %%
# 출력 예시 코드
print("Hello, yeoksam")
# Out:
# Hello, yeoksam

# %%
# 작성일자 : 2020.5.25
# 작성자 : 이원재
# 내용 : 출력 예시 코드
print("Hello, Friends")
# Out:
# Hello, Friends
