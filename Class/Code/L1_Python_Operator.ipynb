# %% [markdown]
# # Python_Operator

# %%
5 + 5
# Out:
# 10

# %%
5 - 3
# Out:
# 2

# %%
5 * 3
# Out:
# 15

# %%
5 / 3
# Out:
# 1.6666666666666667

# %%
# 몫
5 // 3
# Out:
# 1

# %%
# 나머지
5 % 3
# Out:
# 2

# %%
# 5의 제곱, 세제곱
print(5**2)
print(5**3)
# Out:
# 25
# 125

# %%
# 1억
1e8 

# 1 * 10 ** 8 
# 1 * 10의 8제곱
# Out:
# 100000000.0

# %%
# 0.001은 과학적 표기법으로 뭘까?

1e-3
# Out:
# 0.001

# %%
# 0.00045는 뭘까?

4.5e-4
# Out:
# 0.00045

# %%
# 포괄할 수 있는 숫자가 있다

1e30
# Out:
# 1e+30

# %%
1e16
# Out:
# 1e+16

# %%
1e15
# Out:
# 1000000000000000.0

# %%
1e-16
# Out:
# 1e-16

# %%
1e-5
# Out:
# 1e-05

# %%
1e-4
# Out:
# 0.0001

# %%
# 표준

1e-04
# Out:
# 0.0001

# %%
# 5 > 3 결과는?

5 > 3
# Out:
# True

# %% [markdown]
# ## 비교연산자 (True/False)

# %%
5 == 3

# 5 = 3 (대입)
# Out:
# False

# %%
5 != 3
# Out:
# True

# %%
5 >= 3
# Out:
# True

# %%
5 <= 3
# Out:
# False

# %% [markdown]
# ## 논리값 (True/False)

# %%
True # 0이 아닌 것
# Out:
# True

# %%
False # 0
# Out:
# False

# %% [markdown]
# ## 문자 (" ", ' ')

# %%
"안녕"

# 입력: "안녕"   # 입력 표시: 큰따옴표(""), 작은따옴표('')
# 출력: '안녕'   # 출력 표시: 작은따옴표('')
# Out:
# '안녕'

# %%
# False에 해당하는 문자는?

""  # Null
# Out:
# ''

# %%
# True 문자

print(" ") # Space
"0"
# Out:
# '0'

# %% [markdown]
# # Variable (변수)

# %% [markdown]
# ## 변수?
# 하단 Code 참조
#
# ## 변수를 왜 사용?
# - Code 재사용성 유리
# (값을 바꾸고 싶으면, 맨 앞의 num 하나만 바꾸면 됨)
# - 데이터 관리 용이
# - 데이터를 재사용하고 관리하기 위해 변수를 사용한다.
#
# ## 데이터?
# 정보(Ex. 2020. 5. 25, 날씨)

# %%
num = 52132

52132 * 1, 52132 * 2, 52132 * 3
# Out:
# (52132, 104264, 156396)

# %%
num * 1, num * 2, num * 3
# Out:
# (52132, 104264, 156396)
