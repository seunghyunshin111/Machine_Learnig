# %% [markdown]
# # 자료구조(DataStructure)

# %%
toy1 = '우디'
toy2 = '버즈'
toy3 = '보'
toy4 = '포키'

# %% [markdown]
# toy 안에 다 담을 수 없을까?

# %% [markdown]
# ## 리스트

# %%
toy = ['우디', '버즈', '보', '포키']
toy
# Out:
# ['우디', '버즈', '보', '포키']

# %% [markdown]
# 버즈만 지칭하고 싶다면?

# %% [markdown]
# #### 인덱싱

# %%
toy[1] #두번째 데이터
# Out:
# '버즈'

# %%
toy[0] # 첫번째 데이터
# Out:
# '우디'

# %%
toy[-1] #끝번째 데이터
# Out:
# '포키'

# %%
toy[-2] #끝에서 두번째 데이터
# Out:
# '보'

# %% [markdown]
# 연이은 여러개의 데이터를 한번에 지칭하고 싶다면?

# %% [markdown]
# #### 슬라이싱

# %% [markdown]
# 첫번째 ~ 세번째 데이터 = 0번째~2번째 데이터 = 0:3

# %%
toy[0:3]
# Out:
# ['우디', '버즈', '보']

# %%
toy[:3] #양쪽 끝은 칼질할 필요가 없다.
# Out:
# ['우디', '버즈', '보']

# %%
toy[2:]
# Out:
# ['보', '포키']

# %%
toy[:-2]
# Out:
# ['우디', '버즈']

# %%
toy[-2:]
# Out:
# ['보', '포키']

# %%
toy[:] #toy[:-1]가 아니다.
# Out:
# ['우디', '버즈', '보', '포키']

# %% [markdown]
# toy라는 리스트 안에 새로운 데이터를 추가하고 싶다면?

# %% [markdown]
# #### 데이터 추가하기

# %% [markdown]
# - append : 1개/맨끝자리에
# - insert : 1개/원하는 자리에
# - extend : 여러개/맨끝자리에   ==   +

# %%
toy = ['우디', '버즈', '보', '포키']
toy
# Out:
# ['우디', '버즈', '보', '포키']

# %%
#제시를 추가하기
toy.append('제시')

# %%
toy
# Out:
# ['우디', '버즈', '보', '포키', '제시']

# %% [markdown]
# 새로운 데이터를 원하는 위치에 추가하고싶다면?

# %%
toy.insert(3, '슬링키독')
toy
# Out:
# ['우디', '버즈', '보', '슬링키독', '포키', '제시']

# %% [markdown]
# 새로운 데이터 여러개를 한번에 추가하고 싶다면?

# %%
#포테이토 헤드, 햄
toy.extend(['포테이토 헤드', '햄'])
toy
# Out:
# ['우디', '버즈', '보', '슬링키독', '포키', '제시', '포테이토 헤드', '햄']

# %%
toy.append(['포테이토 헤드', '햄'])
toy
# Out:
# ['우디', '버즈', '보', '슬링키독', '포키', '제시', '포테이토 헤드', '햄', ['포테이토 헤드', '햄']]

# %% [markdown]
# #### 데이터 삭제하기

# %% [markdown]
# - remove : 데이터를 명시/같은이름의 데이터가 여러개일 경우, 가장 앞에 있는 데이터 1개 삭제
# - pop : 인덱스를 명시/삭제가 아니라 뽑아내는 것(해당 데이터를 반환)/인덱스 안적으면 -1(마지막 데이터 뽑아냄)
# - clear : 변수 내의 데이터 삭제
# - del : 변수 삭제/인덱스를 명시하여 해당 원소 삭제 가능

# %%
toy
# Out:
# ['우디', '버즈', '보', '슬링키독', '포키', '제시', '포테이토 헤드', '햄', ['포테이토 헤드', '햄']]

# %%
toy.remove(['포테이토 헤드', '햄'])
toy
# Out:
# ['우디', '버즈', '보', '슬링키독', '포키', '제시', '포테이토 헤드', '햄']

# %%
toy.pop()
toy
# Out:
# ['우디', '버즈', '보', '슬링키독', '포키', '제시', '포테이토 헤드']

# %%
#pop과 remove의 또하나의 차이
bo = toy.pop(2)
bo
# Out:
# '보'

# %%
toy
# Out:
# ['우디', '버즈', '슬링키독', '포키', '제시', '포테이토 헤드']

# %%
#응용
buyed = []
buyed.append(toy.pop())
buyed.append(toy.pop())
buyed
# Out:
# ['포테이토 헤드', '제시']

# %%
# 응용 실습
buy = []  # []: Empty list
buy.append(toy.pop(1))
print("구매 상품", buy)
print("남은 상품", toy)


# 구분자 쉼표(,)는 출력되지 않음
# Out:
# 구매 상품 ['버즈']
# 남은 상품 ['우디', '슬링키독', '포키', '제시', '포테이토 헤드', 1]

# %%
toy
# Out:
# ['우디', '슬링키독', '포키', '제시', '포테이토 헤드', 1]

# %%
print('before : ', toy)
toy.clear()

print('after : ', toy)
# Out:
# before :  ['우디', '슬링키독', '포키', '제시', '포테이토 헤드', 1]
# after :  []

# %%
toy.append('버즈')
toy.insert(1, '우디')
toy.extend(['제시', '보'])
toy
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-205-f6d3f466d5eb> in <module>()
# ----> 1 toy.append('버즈')
#       2 toy.insert(1, '우디')
#       3 toy.extend(['제시', '보'])
#       4 toy
#
# NameError: name 'toy' is not defined

# %%
del toy[0]
toy
# Out:
# ['우디', '제시', '보']

# %%
del(toy[-1])
toy
# Out:
# ['우디', '제시']

# %%
del(toy)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-204-328bf7aee632> in <module>()
# ----> 1 del(toy)
#
# NameError: name 'toy' is not defined

# %% [markdown]
# toy # NameError: name 'toy' is not defined

# %% [markdown]
# #### 리스트 정렬하기

# %%
hero = ['토르', '아이언맨', '헐크', '캡틴아메리카']
hero
# Out:
# ['토르', '아이언맨', '헐크', '캡틴아메리카']

# %%
hero.sort()
hero # 사전식 기준 정렬
# Out:
# ['아이언맨', '캡틴아메리카', '토르', '헐크']

# %%
hero.reverse()
hero
# Out:
# ['헐크', '토르', '캡틴아메리카', '아이언맨']

# %% [markdown]
# hero는 그대로 두고, 새로운 변수를 만들어서 정렬시키고싶다면?

# %%
hero = ['토르', '아이언맨', '헐크', '캡틴아메리카']

hero_sorted = sorted(hero)

print('hero:', hero)
print('sorted:', hero_sorted)

#reversed(hero)도 가능
# Out:
# hero: ['토르', '아이언맨', '헐크', '캡틴아메리카']
# sorted: ['아이언맨', '캡틴아메리카', '토르', '헐크']

# %%
hero = ['토르', '아이언맨', '헐크', '캡틴아메리카']

hero_revsd = list(reversed(hero))
print(hero_revsd)
# Out:
# ['캡틴아메리카', '헐크', '아이언맨', '토르']

# %% [markdown]
# 사전식 기준말고 문자열의 길이를 기준으로 정렬하고 싶다면?

# %%
hero.sort(key=len) #len = 길이
hero
# Out:
# ['토르', '헐크', '아이언맨', '캡틴아메리카']

# %% [markdown]
# 리스트 안에 데이터가 몇개 들어있을까?

# %%
hero = ['토르', '아이언맨', '헐크', '캡틴아메리카']
hero
# Out:
# ['토르', '아이언맨', '헐크', '캡틴아메리카']

# %%
len(hero) # 리스트의 길이 = 원소의 개수
# Out:
# 4

# %%
hero.extend(['스파이더맨', '앤트맨'])
hero
# Out:
# ['토르', '아이언맨', '헐크', '캡틴아메리카', '스파이더맨', '앤트맨']

# %%
len(hero)
# Out:
# 6

# %% [markdown]
# '아이언맨'이 몇번째 자리에 있는지 궁금하다면?

# %%
hero.index('아이언맨')
# Out:
# 1

# %% [markdown]
# '아이언맨'이 총 몇개가 있는지 궁금하다면?

# %%
hero.count('아이언맨')
# Out:
# 1

# %% [markdown]
# 앤트맨은 있을까?

# %%
'앤트맨' in hero
# Out:
# True

# %% [markdown]
# #### 이외의 알아두면 좋은 것들

# %% [markdown]
# 1. 리스트의 덧셈은 extend 다.

# %%
hero1 = ['iron-man', 'vision', 'spiderman']
hero2 = ['captin', 'black-widow', 'blackpanser']

# %%
hero = hero1 + hero2
hero
# Out:
# ['iron-man', 'vision', 'spiderman', 'captin', 'black-widow', 'blackpanser']

# %% [markdown]
# 2. 리스트의 곱셈은 복제다.

# %%
num = [1, 2, 3]
num = num*3
num
# Out:
# [1, 2, 3, 1, 2, 3, 1, 2, 3]

# %% [markdown]
# 3. 리스트는 다국적사회다.

# %%
society = ['철수', 'Tom']
society.append(1)
society
# Out:
# ['철수', 'Tom', 1]

# %%
society.append(5.5)
society.append(True)

hero = ['아이언맨', '블랙팬서']
society.append(hero)
society
# Out:
# ['철수', 'Tom', 1, 5.5, True, ['아이언맨', '블랙팬서']]

# %% [markdown]
# ## Tuple

# %% [markdown]
# ### 튜플의 특징

# %% [markdown]
# - 변환 시킬 수 X
# - 괄호 쓸 필요 X
# - 여러개를 어떤 괄호를 쓰지않고,
# 쉼표로 구분하여 하나의 데이터로 반환하면 Tuple이다.

# %%
ArbNight = ('알라딘', '자스민', '지니')
type(ArbNight)
# Out:
# tuple

# %%
# ArbNight.append('sultan')

# %%
ArbNight = '알라딘', '자스민', '지니'
type(ArbNight)
# Out:
# tuple

# %%
ArbNight
# Out:
# ('알라딘', '자스민', '지니')

# %%
ArbNight[0]
# Out:
# '알라딘'

# %%
ArbNight[:2]
# Out:
# ('알라딘', '자스민')

# %%
Hero = ['아이언맨', '블랙팬서', '블랙위도우']
Hero[0] = '앤트맨'
Hero
# Out:
# ['앤트맨', '블랙팬서', '블랙위도우']

# %% [markdown]
# 리스트는 데이터를 변형할 수 있다.
# 하지만, 튜플은 불가하다.

# %%
# ArbNight[0] = '아부' #TypeError: 'tuple' object does not support item assignment
# ArbNight

# %% [markdown]
# 리스트에 사용하던 데이터 추가/삭제 기능을 모두 사용할 수 없다.

# %%
# ArbNight.append('아부') #AttributeError: 'tuple' object has no attribute 'append'
# ArbNight.insert(1, '아부')
# ArbNight.extend(['아부'])
# ArbNight.remove('알라딘')
# ArbNight.pop()
# ArbNight.clear()
# del ArbNight[-1]
# ArbNight

# %% [markdown]
# 튜플에 데이터를 추가하고 싶다면?

# %%
ArbNight = ArbNight + ('아부', '자파')
ArbNight


# 튜플에서 유일하게 수정 가능! (변경 및 삭제는 안 됨!)
# Out:
# ('알라딘', '자스민', '지니', '아부', '자파')

# %% [markdown]
# 튜플의 데이터 변경, 삭제는 불가

# %% [markdown]
# 이외의 다른 기능들은 리스트에서 사용하던 것들 그대로 사용할 수 있다.
# 한번 되는 것과 안되는 것을 직접 시도해보고 숙지하자.

# %% [markdown]
# ### 해체할당기능

# %%
cup1 = 'water'
cup2 = 'pocari'

# cup1 <- 'pocari', cup2 <- 'water'로 바꾸고싶다면?

# %%
# 일반상식) 
# cup3 <- cup1(water)
# cup1 <- cup2(pocari)
# cup2 <- cup3(water)

# result : cup1(pocari), cup2(water)

# %%
cup1, cup2 = 'water', 'pocari'
cup1, cup2 = cup2, cup1
print('cup1:', cup1)
print('cup2:', cup2)
# Out:
# cup1: pocari
# cup2: water

# %%
cup = cup1, cup2
type(cup)
# Out:
# tuple

# %%
cup1, cup2 #tuple
# Out:
# ('pocari', 'water')

# %%
# 파이썬 개체 할당 기능

a, b = 1, 2
a, b = b, a
print(a, b)
# Out:
# 2 1

# %% [markdown]
# ## Set(집합)

# %% [markdown]
# ### Set의 특징

# %% [markdown]
# - 중복을 제거 (중복허용X)
# - 순서 X (인덱싱 할 수 X)

# %%
Company = ['네이버', '다음카카오', '삼성', 'LG', '네이버', '삼성']
len(Company)
# Out:
# 6

# %% [markdown]
# 리스트 안에 서로 다른 데이터가 총 몇개가 있을까?

# %%
Company = set(Company)
Company
# Out:
# {'LG', '네이버', '다음카카오', '삼성'}

# %%
len(Company)
# Out:
# 4

# %%
#Company[0] # TypeError: 'set' object is not subscriptable

# %% [markdown]
# 리스트 안에 중복된 데이터가 들어가있을 경우, 중복제거하고 싶을 때 이렇게 한다.

# %%
Company = ['네이버', '다음카카오', '삼성', 'LG', '네이버', '삼성', 'SK', 'SK', 'LG', '네이버', '롯데']
Company = list(set(Company))
Company
# Out:
# ['네이버', '다음카카오', '삼성', 'LG', 'SK', '롯데']

# %% [markdown]
# ### set 변환하기

# %% [markdown]
# 1) 추가하기
# - add : 1개
# - update : 여러개
#
# 2) 삭제하기
# - remove : 1개/없는 걸 없애라고하면 key error
# - discard : 1개/없는 걸 없애라고해도 에러 X

# %%
Company = {'삼성', '다음카카오', '네이버', 'LG', '롯데', 'SK'}
Company.add('현대')
Company
# Out:
# {'LG', 'SK', '네이버', '다음카카오', '롯데', '삼성', '현대'}

# %%
Company.update(['포스코', 'GS'])
Company
# Out:
# {'GS', 'LG', 'SK', '네이버', '다음카카오', '롯데', '삼성', '포스코', '현대'}

# %%
Company.remove('롯데')
Company
# Out:
# {'GS', 'LG', 'SK', '네이버', '다음카카오', '삼성', '포스코', '현대'}

# %%
# Company.remove('롯데') #KeyError: '롯데'
# Company

# %%
Company.discard('포스코')
Company
# Out:
# {'GS', 'LG', 'SK', '네이버', '다음카카오', '삼성', '현대'}

# %%
Company.discard('포스코')
Company
# Out:
# {'GS', 'LG', 'SK', '네이버', '다음카카오', '삼성', '현대'}

# %%
Company.discard('포스코')
Company
# Out:
# {'GS', 'LG', 'SK', '네이버', '다음카카오', '삼성', '현대'}

# %% [markdown]
# ### 집합연산

# %%
movie1 = {'ones', 'avengers', 'aladin'}
movie2 = {'avengers', 'aladin', 'toystory'}

# %%
#합집합
movie1 | movie2 #movie1.union(movie2)
# Out:
# {'aladin', 'avengers', 'ones', 'toystory'}

# %%
# 합 & 교 실습
a = movie1 | movie2
b = movie1 & movie2
print(a, b)
# Out:
# {'aladin', 'toystory', 'ones', 'avengers'} {'aladin', 'avengers'}

# %%
#교집합
movie1 & movie2 #movie1.intersection(movie2)
# Out:
# {'aladin', 'avengers'}

# %%
# 수업 실습

hero = ['토르', '아이언맨', '헐크', '블랙위도우']
avengers = ['캡틴아메리카', '토르', '아이언맨', '토르토르']

# %%
# 두 변수에 총 몇 명의 히어로가 있는지 맞추시오.

len(set(hero) | set(avengers))
len(set(hero + avengers))
# set(hero + avengers)
# Out:
# 6

# %%
#차집합
movie1 - movie2 #movie1.difference(movie2)
# Out:
# {'ones'}

# %%
#대칭차집합
movie1^movie2

# 교집합을 빼버린 것. (독자적인 데이터)
# Out:
# {'ones', 'toystory'}

# %% [markdown]
# ## Dictionary(사전)

# %% [markdown]
# ### 딕셔너리의 특징

# %% [markdown]
# - 순서 X
# - key와 value의 쌍으로 이루어져 있음

# %%
per_info = {'이름': '알디노', '직업': ['개발자', '강사']}
per_info
# Out:
# {'이름': '알디노', '직업': ['개발자', '강사']}

# %%
per_info.keys()
# Out:
# dict_keys(['이름', '직업'])

# %%
type(per_info.keys())
# Out:
# dict_keys

# %%
per_info.values()
# Out:
# dict_values(['알디노', ['개발자', '강사']])

# %%
type(per_info.values())
# Out:
# dict_values

# %%
per_info.items()
# Out:
# dict_items([('이름', '알디노'), ('직업', ['개발자', '강사'])])

# %%
type(per_info.items())
# Out:
# dict_items

# %%
per_keys = list(per_info.keys())
per_vals = list(per_info.values())
per_itms = list(per_info.items())
print(per_keys)
print(per_vals)
print(per_itms)
# Out:
# ['이름', '직업']
# ['알디노', ['개발자', '강사']]
# [('이름', '알디노'), ('직업', ['개발자', '강사'])]

# %% [markdown]
# 이렇게 키, 밸류, 아이템에 접근하고, 다룰 수 있다는 것을 잘 기억해두자. 나중에 쓸일이 종종 있다.

# %% [markdown]
# 딕셔너리에서 '이름'을 조회하고 싶다면?

# %%
per_info['이름'] #인덱싱을 key값으로
# Out:
# '알디노'

# %% [markdown]
# #### 데이터 추가 & 변경하기

# %%
per_info = {'이름': '알디노', '직업': ['개발자', '강사']}
per_info
# Out:
# {'이름': '알디노', '직업': ['개발자', '강사']}

# %%
#전공분야 추가
per_info['전공분야'] = '전자전기공학'
per_info
# Out:
# {'이름': '알디노', '전공분야': '전자전기공학', '직업': ['개발자', '강사']}

# %%
#전공분야 변경
per_info['전공분야'] = '머신러닝'
per_info
# Out:
# {'이름': '알디노', '전공분야': '머신러닝', '직업': ['개발자', '강사']}

# %%
len(per_info)
# Out:
# 3

# %%
# {} = Empty Dic
# () = Empty tuple
# [] = Empty list

{'name':'신승현'}
# Out:
# {'name': '신승현'}

# %%
# 수업 실습

data = {}
data['name'] = '신승현'
data['성격'] = '외향적'
data
# Out:
# {'name': '신승현', '성격': '외향적'}

# %%
data['성격'] = '내향적'
data
# Out:
# {'name': '신승현', '성격': '내향적'}

# %%
# 수업 실습 2

data = {}
data['name'] = '신승현', 'kelly'
data['성격'] = '외향적', '내향적'
data

# data = {name : []}
# Out:
# {'name': ('신승현', 'kelly'), '성격': ('외향적', '내향적')}

# %%
# 수업 실습 2.2
data1 = {}
data1['name'] = ['신승현', '김윤영', '이예슬', '박민서']
data1
# Out:
# {'name': ['신승현', '김윤영', '이예슬', '박민서']}

# %%
# 수업 실습 2.3

# data = {}
# data['name'] = ['신승현']
# data.append{'name', '김윤영'}  # 실패

data['name'] = []
data['name'].append('김윤영')
data['name'].extend(['박민서', '이예슬'])
data
# Out:
# {'name': ['김윤영', '박민서', '이예슬']}

# %% [markdown]
# #### 데이터 삭제하기

# %%
per_info = {'이름': '알디노', '직업': ['개발자', '강사'], '전공분야' : '머신러닝', '취미': ['볼링', '탁구', '수영'], '고향': '대전'}
per_info
# Out:
# {'고향': '대전',
#  '이름': '알디노',
#  '전공분야': '머신러닝',
#  '직업': ['개발자', '강사'],
#  '취미': ['볼링', '탁구', '수영']}

# %%
# .pop('key') == Key값만 삭제
# .remove(['value']) == Value값만 삭제

hobby = per_info.pop('취미') #index 대신 key
per_info
# Out:
# {'고향': '대전', '이름': '알디노', '전공분야': '머신러닝', '직업': ['개발자', '강사']}

# %%
hobby
# Out:
# ['볼링', '탁구', '수영']

# %%
del(per_info['고향']) #del per_info['고향']
per_info
# Out:
# {'이름': '알디노', '전공분야': '머신러닝', '직업': ['개발자', '강사']}

# %%
per_info.clear()
per_info
# Out:
# {}

# %%
del per_info

# %% [markdown]
# ### 딕셔너리 in 용법

# %% [markdown]
# 앞에서 감을 잡았을지 모르겠지만, 딕셔너리에서는 Value가 아니라, Key가 메인이다.
# '학교'라는 단어의 사전적 의미가 궁금하다고 가정해보자.
# 그럼 사전에서 '학교'라는 단어를 검색하지 않겠는가.
# 여기서 '학교' = key , '학교'에 대한 사전적 설명 = value 에 해당한다.
#
# 즉, 딕셔너리에서 in 용법을 쓸 때는 당연하게도(?) key값으로 검색해야 한다.

# %%
per_info = {'이름': '알디노', '직업': ['개발자', '강사'], '전공분야' : '머신러닝', '취미': ['볼링', '탁구', '수영'], '고향': '대전'}
per_info
# Out:
# {'고향': '대전',
#  '이름': '알디노',
#  '전공분야': '머신러닝',
#  '직업': ['개발자', '강사'],
#  '취미': ['볼링', '탁구', '수영']}

# %%
# in == Key값으로 검색

'이름' in per_info
# Out:
# True

# %%
'특기' in per_info
# Out:
# False

# %%
'취미' in per_info
# Out:
# True

# %%
#응용
'독서' in per_info['취미']
# Out:
# False

# %%
# 수업 응용
'음악' in per_info['취미']
# Out:
# False

# %% [markdown]
# ### 빈 딕셔너리 선언

# %%
sample_list = [] # empty list
sample_tuple = () # empty tuple
sample = {} # empty set일까 empty dict일까

# %%
type(sample) #정답은 empty dict
# Out:
# dict

# %% [markdown]
# 아래와 같은 NaverWebtoon을 빈딕셔너리를 이용해 만들어보자.

# %%
# NaverWebtoon =  [
#                 {'작가': 'SIU', '평점': '9.94', '제목': '신의 탑'},
#                 {'작가': '조용석', '평점': '9.82', '제목': '뷰티풀 군바리'},
#                 {'작가': '영파카', '평점': '9.92', '제목': '니편내편'}
#                  ]

# %%
# 풀이를 보지않고, 직접 코드를 작성해보자

# NaverWebtoon = {}
# NaverWebtoon['작가'] = ['SIU', '조용석', '영파카']
# NaverWebtoon = []
# NaverWebtoon.append({'작가' : ['SIU', '조용석', '영파카']})
# NaverWebtoon.append({'평점' : ['9.94', '9.82', '9.92']})
# NaverWebtoon.append({'제목' : ['신의 탑', '뷰티풀', '니편내편']})
# NaverWebtoon

# %%
# # 내 코드

# NaverWebtoon = {}
# NaverWebtoon['작가'] = ['SIU', '조용석', '영파카']
# NaverWebtoon['평점'] = ['9.94', '9.82', '9.92']
# NaverWebtoon['제목'] = ['신의 탑', '뷰티풀', '니편내편']
# NaverWebtoon

# %% [markdown]
# ##### 풀이

# %%
#@title
NaverWebtoon = [{}, {}, {}]

# %%
NaverWebtoon[0]
# Out:
# {}

# %%
NaverWebtoon[0]['작가'] = 'SIU'
NaverWebtoon[0]['평점'] = '9.94'
NaverWebtoon[0]['제목'] = '신의 탑'
NaverWebtoon
# Out:
# [{'작가': 'SIU', '제목': '신의 탑', '평점': '9.94'},
#  {'평점': ['9.94', '9.82', '9.92']},
#  {'제목': ['신의 탑', '뷰티풀', '니편내편']}]

# %%
NaverWebtoon[0]['작가']
# Out:
# 'SIU'

# %%
NaverWebtoon[1]['작가'] = '조용석'
NaverWebtoon[1]['평점'] = '9.82'
NaverWebtoon[1]['제목'] = '뷰티풀 군바리'
NaverWebtoon
# Out:
# [{'작가': 'SIU', '제목': '신의 탑', '평점': '9.94'},
#  {'작가': '조용석', '제목': '뷰티풀 군바리', '평점': '9.82'},
#  {}]

# %%
NaverWebtoon[2]['작가'] = '영파카'
NaverWebtoon[2]['평점'] = '9.92'
NaverWebtoon[2]['제목'] = '니편내편'
NaverWebtoon
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-309-dc18b4720ddb> in <module>()
# ----> 1 NaverWebtoon[2]['작가'] = '영파카'
#       2 NaverWebtoon[2]['평점'] = '9.92'
#       3 NaverWebtoon[2]['제목'] = '니편내편'
#       4 NaverWebtoon
#
# KeyError: 2

# %%
## 풀이 후, 원하는 답 안 보고 작성해보기! 
# 문제
# NaverWebtoon =  [
#                 {'작가': 'SIU', '평점': '9.94', '제목': '신의 탑'},
#                 {'작가': '조용석', '평점': '9.82', '제목': '뷰티풀 군바리'},
#                 {'작가': '영파카', '평점': '9.92', '제목': '니편내편'}
#                  ]

NaverWebtoon = [{}, {}, {}]
NaverWebtoon[0]['작가'] = 'SIU'
NaverWebtoon[0]['평점'] = '9.94'
NaverWebtoon[0]['제목'] = '신의 탑'

NaverWebtoon[1]['작가'] = '조용석'
NaverWebtoon[1]['평점'] = '9.82'
NaverWebtoon[1]['제목'] = '뷰티풀'

NaverWebtoon[2]['작가'] = '영파카'
NaverWebtoon[2]['평점'] = '9.92'
NaverWebtoon[2]['제목'] = '니편내편'

NaverWebtoon
# Out:
# [{'작가': 'SIU', '제목': '신의 탑', '평점': '9.94'},
#  {'작가': '조용석', '제목': '뷰티풀', '평점': '9.82'},
#  {'작가': '영파카', '제목': '니편내편', '평점': '9.92'}]
